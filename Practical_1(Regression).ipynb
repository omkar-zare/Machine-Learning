# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model, metrics

# %%
boston_data = pd.read_csv('C:/Users/Omkar/Desktop/all files/Programs/ML prac/Dataset/Boston.csv') 
boston_data
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
boston_data.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
boston_data.drop('ID', axis=1, inplace=True)
boston_data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston_data.columns = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax','ptratio', 'black', 'lstat', 'prices']
boston_data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  prices
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# ...

# %%
boston_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  prices   506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
boston_data.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# prices     0
# dtype: int64

# %%
x = boston_data[['crim','zn','indus','chas', 'nox', 'rm', 'age', 'dis', 'rad','tax','ptratio','black','lstat','prices']]==0
x = x.sum()
print(x)
# Out:
# crim         0
# zn         372
# indus        0
# chas       471
# nox          0
# rm           0
# age          0
# dis          0
# rad          0
# tax          0
# ptratio      0
# black        0
# lstat        0
# prices       0
# dtype: int64

# %%
boston_data=boston_data.drop(columns=['zn', 'chas'])
boston_data
# Out:
#         crim  indus    nox     rm   age     dis  rad  tax  ptratio   black  \
# 0    0.00632   2.31  0.538  6.575  65.2  4.0900    1  296     15.3  396.90
# 1    0.02731   7.07  0.469  6.421  78.9  4.9671    2  242     17.8  396.90
# 2    0.02729   7.07  0.469  7.185  61.1  4.9671    2  242     17.8  392.83
# 3    0.03237   2.18  0.458  6.998  45.8  6.0622    3  222     18.7  394.63
# 4    0.06905   2.18  0.458  7.147  54.2  6.0622    3  222     18.7  396.90
# ..       ...    ...    ...    ...   ...     ...  ...  ...      ...     ...
# 501  0.06263  11.93  0.573  6.593  69.1  2.4786    1  273     21.0  391.99
# 502  0.04527  11.93  0.573  6.120  76.7  2.2875    1  273     21.0  396.90
# 503  0.06076  11.93  0.573  6.976  91.0  2.1675    1  273     21.0  396.90
# 504  0.10959  11.93  0.573  6.794  89.3  2.3889    1  273     21.0  393.45
# 505  0.04741  11.93  0.573  6.030  80.8  2.5050    1  273     21.0  396.90
#
#      lstat  prices
# 0     4.98    24.0
# 1     9.14    21.6
# ...

# %%
from sklearn import preprocessing

# %%
boston_data
# Out:
#         crim  indus    nox     rm   age     dis  rad  tax  ptratio   black  \
# 0    0.00632   2.31  0.538  6.575  65.2  4.0900    1  296     15.3  396.90
# 1    0.02731   7.07  0.469  6.421  78.9  4.9671    2  242     17.8  396.90
# 2    0.02729   7.07  0.469  7.185  61.1  4.9671    2  242     17.8  392.83
# 3    0.03237   2.18  0.458  6.998  45.8  6.0622    3  222     18.7  394.63
# 4    0.06905   2.18  0.458  7.147  54.2  6.0622    3  222     18.7  396.90
# ..       ...    ...    ...    ...   ...     ...  ...  ...      ...     ...
# 501  0.06263  11.93  0.573  6.593  69.1  2.4786    1  273     21.0  391.99
# 502  0.04527  11.93  0.573  6.120  76.7  2.2875    1  273     21.0  396.90
# 503  0.06076  11.93  0.573  6.976  91.0  2.1675    1  273     21.0  396.90
# 504  0.10959  11.93  0.573  6.794  89.3  2.3889    1  273     21.0  393.45
# 505  0.04741  11.93  0.573  6.030  80.8  2.5050    1  273     21.0  396.90
#
#      lstat  prices
# 0     4.98    24.0
# 1     9.14    21.6
# ...

# %%
std = preprocessing.StandardScaler()

# %%
y = boston_data['prices']
bos = boston_data.drop(['prices'], axis=1)
bos = std.fit_transform(bos)
print(bos[0])
# Out:
# [-0.41978194 -1.2879095  -0.14421743  0.41367189 -0.12001342  0.1402136
#  -0.98284286 -0.66660821 -1.45900038  0.44105193 -1.0755623 ]

# %%
boston_data = pd.DataFrame(bos)
boston_data['prices'] = y
boston_data.columns = ['crim', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 
        'tax','ptratio', 'black', 'lstat', 'prices']

# %%
boston_data
# Out:
#          crim     indus       nox        rm       age       dis       rad  \
# 0   -0.419782 -1.287909 -0.144217  0.413672 -0.120013  0.140214 -0.982843
# 1   -0.417339 -0.593381 -0.740262  0.194274  0.367166  0.557160 -0.867883
# 2   -0.417342 -0.593381 -0.740262  1.282714 -0.265812  0.557160 -0.867883
# 3   -0.416750 -1.306878 -0.835284  1.016303 -0.809889  1.077737 -0.752922
# 4   -0.412482 -1.306878 -0.835284  1.228577 -0.511180  1.077737 -0.752922
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229  0.115738  0.158124  0.439316  0.018673 -0.625796 -0.982843
# 502 -0.415249  0.115738  0.158124 -0.234548  0.288933 -0.716639 -0.982843
# 503 -0.413447  0.115738  0.158124  0.984960  0.797449 -0.773684 -0.982843
# 504 -0.407764  0.115738  0.158124  0.725672  0.736996 -0.668437 -0.982843
# 505 -0.415000  0.115738  0.158124 -0.362767  0.434732 -0.613246 -0.982843
#
#           tax   ptratio     black     lstat  prices
# ...

# %%
for i in boston_data.columns:
  plt.scatter(boston_data[i], boston_data['prices'])
  plt.xlabel(i)
  plt.ylabel('house prices')
  plt.show()

# %%
from sklearn import linear_model

# %%
Y = boston_data['prices']
X = boston_data.drop("prices", axis=1)
X = np.array(X)
X.reshape(1, -1)
# Out:
# array([[-0.41978194, -1.2879095 , -0.14421743, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.2, random_state=4)

# %%
regr = linear_model.LinearRegression()
regr.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
plt.scatter(regr.predict(train_x),regr.predict(train_x)-train_y,color='green',s=10,label='Train Data')
plt.scatter(regr.predict(test_x),regr.predict(test_x)-test_y,color='blue',s=10,label='Test Data')
plt.hlines(y=0,xmin=0,xmax=50)
plt.legend(loc='upper right')
plt.title("Residual errors")
plt.show()

# %%
y_pred = regr.predict(test_x)

# %%
regr.score(test_x, test_y)
# Out:
# 0.7221157909282524

# %%
regr.score(train_x, train_y)
# Out:
# 0.7284850173701609

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(test_y, y_pred))
print('MSE:', metrics.mean_squared_error(test_y, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(test_y, y_pred)))
# Out:
# MAE: 3.301709309745185
# MSE: 25.812448636118003
# RMSE: 5.080595303320075

# %%
plt.scatter(test_y,y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')
